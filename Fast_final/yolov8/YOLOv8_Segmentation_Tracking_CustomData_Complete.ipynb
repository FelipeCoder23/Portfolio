# %% [markdown]
# # Before Running the Script Please Make Sure you Select the Run Time as GPU

# %% [markdown]
# #**Import the Required Libraries**

# %%
from IPython.display import Image

# %% [markdown]
# #**Clone the Github Repo**

# %%
# !git clone https://github.com/MuhammadMoinFaisal/YOLOv8_Segmentation_DeepSORT_Object_Tracking.git
# Out:
# Cloning into 'YOLOv8_Segmentation_DeepSORT_Object_Tracking'...
# remote: Enumerating objects: 214, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 214 (delta 46), reused 70 (delta 31), pack-reused 119
# Receiving objects: 100% (214/214), 12.76 MiB | 11.33 MiB/s, done.
# Resolving deltas: 100% (76/76), done.

# %%
# !pwd
# Out:
# /home/felipe-alvarez/code/YOLOv8_Segmentation_DeepSORT_Object_Tracking

# %% [markdown]
# ##Setting the Current Directory

# %%
# %cd /content/YOLOv8_Segmentation_DeepSORT_Object_Tracking
# Out:
# /content/YOLOv8_Segmentation_DeepSORT_Object_Tracking

# %% [markdown]
# ##Install all the Dependencies

# %%
# !pip install -e '.[dev]'
# Out:
# Obtaining file:///home/felipe-alvarez/code/YOLOv8_Segmentation_DeepSORT_Object_Tracking
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.3
#     Uninstalling ultralytics-8.0.3:
#       Successfully uninstalled ultralytics-8.0.3
#   Running setup.py develop for ultralytics
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 24.0
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %% [markdown]
# ##Moving to the Required Directory

# %%
# %cd /content/YOLOv8_Segmentation_DeepSORT_Object_Tracking/ultralytics/yolo/v8/segment
# Out:
# [Errno 2] No such file or directory: '/content/YOLOv8_Segmentation_DeepSORT_Object_Tracking/ultralytics/yolo/v8/segment'
# /home/felipe-alvarez/code/YOLOv8_Segmentation_DeepSORT_Object_Tracking
# /home/felipe-alvarez/.pyenv/versions/3.10.6/envs/yoloSegmentacion/lib/python3.10/site-packages/IPython/core/magics/osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %% [markdown]
# #**Training the Custom Model**

# %%
HOME = '/content/YOLOv8_Segmentation_DeepSORT_Object_Tracking/ultralytics/yolo/v8/segment'

# %%
# %cd {HOME}
# Out:
# /content/YOLOv8_Segmentation_DeepSORT_Object_Tracking/ultralytics/yolo/v8/segment

# %%
# %cd ultralytics/yolo/v8/segment
# Out:
# /home/felipe-alvarez/code/YOLOv8_Segmentation_DeepSORT_Object_Tracking/ultralytics/yolo/v8/segment
# /home/felipe-alvarez/.pyenv/versions/3.10.6/envs/yoloSegmentacion/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %cd ultralytics/yolo/v8/segment
# Out:
# /home/felipe-alvarez/code/YOLOv8_Segmentation_DeepSORT_Object_Tracking/ultralytics/yolo/v8/segment
# /home/felipe-alvarez/.pyenv/versions/3.10.6/envs/yoloSegmentacion/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %ls
# Out:
# arbitro-4/          __init__.py   test1.mp4  train.py    yolov8l-seg.pt
# best2.pt            predict.log   test2.mp4  valid/
# best.pt             predict.py    test3.mp4  val.log
# data.yaml           __pycache__/  train/     val.py
# deep_sort_pytorch/  test/         train.log  yolov8l.pt

# %%
# !pip install easydict
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 24.0
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
# %pwd
# Out:
# '/home/felipe-alvarez/code/YOLOv8_Segmentation_DeepSORT_Object_Tracking/ultralytics/yolo/v8/segment'

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="dP9i7qb9bMylCvtBj32G")
project = rf.workspace("tests-umzus").project("arbitro")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
#   Using cached roboflow-1.1.23-py3-none-any.whl (71 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# ...
#   Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...
#   Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# ...
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# ...
#   Using cached opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
# ...
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# ...
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: certifi
# ...

# %%
# %ls
# Out:
# arbitro-4/  deep_sort_pytorch/  __pycache__/  train.log  val.py
# best2.pt    __init__.py         test/         train.py   yolov8l-seg.pt
# data.yaml   predict.py          train/        valid/

# %%
# !python train.py model=yolov8l.pt data=arbitro-4/data.yaml epochs=50 imgsz=640 batch=8
# Out:
# yolo/engine/trainer: task=detect, mode=train, model=yolov8l.pt, data=arbitro-4/data.yaml, epochs=50, patience=50, batch=8, imgsz=640, save=True, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=False, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, retina_masks=False, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmu
# ...

# %% [markdown]
# #**Checking the Files inside the Train Folder**

# %%
# !python val_detect.py model=best.pt data=arbitro-4/data.yaml
# Out:
# Ultralytics YOLOv8.0.3 🚀 Python-3.10.6 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# Fusing layers...
# Model summary: 268 layers, 43608150 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning /home/felipe-alvarez/code/YOLOv8_Segmentation_DeepSORT_Object_Trac
#                  Class     Images  Instances      Box(P          R      mAP50  mValor de mi: 6
# Forma de prediction: torch.Size([16, 6, 9261])
# Forma de prediction[:, 4:mi]: torch.Size([16, 2, 9261])
#                  Class     Images  Instances      Box(P          R      mAP50  mException in thread Thread-3 (plot_images):
# Traceback (most recent call last):
#   File "/home/felipe-alvarez/.pyenv/versions/3.10.6/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/home/felipe-alvarez/.pyenv/versions/3.10.6/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
# ...

# %%
# !python predict_detect.py model=best.pt source=test7.mp4
# Out:
# [2024-03-11 14:25:11,826][root.tracker][INFO] - Loading weights from deep_sort_pytorch/deep_sort/deep/checkpoint/ckpt.t7... Done!
# Ultralytics YOLOv8.0.3 🚀 Python-3.10.6 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# Fusing layers...
# Model summary: 268 layers, 43608150 parameters, 0 gradients, 164.8 GFLOPs
# Valor de mi: 6
# Forma de prediction: torch.Size([1, 6, 5040])
# Forma de prediction[:, 4:mi]: torch.Size([1, 2, 5040])
# video 1/1 (1/64) /home/felipe-alvarez/code/YOLOv8_Segmentation_DeepSORT_Object_Tracking/ultralytics/yolo/v8/segment/test7.mp4: 384x640 86.2ms
# Valor de mi: 6
# Forma de prediction: torch.Size([1, 6, 5040])
# Forma de prediction[:, 4:mi]: torch.Size([1, 2, 5040])
# video 1/1 (2/64) /home/felipe-alvarez/code/YOLOv8_Segmentation_DeepSORT_Object_Tracking/ultralytics/yolo/v8/segment/test7.mp4: 384x640 14.5ms
# Valor de mi: 6
# Forma de prediction: torch.Size([1, 6, 5040])
# Forma de prediction[:, 4:mi]: torch.Size([1, 2, 5040])
# ...
